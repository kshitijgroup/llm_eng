# %%
from hello import hello, app

# %%
with app.run():
    reply = hello.local()
reply

# %%
with app.run():
    reply = hello.remote()
reply

# %%
import modal
from llama import app, generate

with modal.enable_output():
    with app.run():
        result=generate.remote("Never gonna give you up, never gonna")
result
# Out:
# ✓ Initialized. View run at
# https://modal.com/apps/kshitijchaudhary21/main/ap-FxfPVlFq20XyEIEwcfzEDY
# ⠋ Initializing...
# ⠸ Creating objects...objects...
# └── ⠋ Creating mount /Users/kshitijchaudhary/llm_eng/llm_eng/week8/llama.py:
# ⠦ Creating objects...
# └── ⠸ Creating mount /Users/kshitijchaudhary/llm_eng/llm_eng/week8/llama.py:
# ⠏ Creating objects...
# └── ⠦ Creating mount /Users/kshitijchaudhary/llm_eng/llm_eng/week8/llama.py:
# ⠹ Creating objects...
# └── ⠏ Creating mount /Users/kshitijchaudhary/llm_eng/llm_eng/week8/llama.py:
# ⠴ Creating objects...
# └── ⠹ Creating mount /Users/kshitijchaudhary/llm_eng/llm_eng/week8/llama.py:
# ⠏ Creating objects...
# └── ⠴ Creating mount /Users/kshitijchaudhary/llm_eng/llm_eng/week8/llama.py:
# ⠹ Creating objects...
# └── ⠏ Creating mount /Users/kshitijchaudhary/llm_eng/llm_eng/week8/llama.py:
# ⠴ Creating objects...
# └── ⠹ Creating mount /Users/kshitijchaudhary/llm_eng/llm_eng/week8/llama.py:
# ⠇ Creating objects...
# └── ⠴ Creating mount /Users/kshitijchaudhary/llm_eng/llm_eng/week8/llama.py:
# ⠙ Creating objects...
# ├── 🔨 Created mount /Users/kshitijchaudhary/llm_eng/llm_eng/week8/llama.py
# ⠹ Creating objects......
# ├── 🔨 Created mount /Users/kshitijchaudhary/llm_eng/llm_eng/week8/llama.py
# └── 🔨 Created function generate.
# ✓ Created objects.
# ├── 🔨 Created mount /Users/kshitijchaudhary/llm_eng/llm_eng/week8/llama.py
# └── 🔨 Created function generate.
# ⠏ Worker assigned... View app at
# ⠹ Worker assigned... View app at wcfzEDY
# ⠴ Worker assigned... View app at wcfzEDY
# ⠏ Worker assigned... View app at wcfzEDY
# ⠹ Worker assigned... View app at wcfzEDY
# ⠴ Worker assigned... View app at wcfzEDY
# ⠇ Worker assigned... View app at wcfzEDY
# ⠙ Worker assigned... View app at wcfzEDY
# ⠼ Worker assigned... View app at wcfzEDY
# ⠇ Worker assigned... View app at wcfzEDY
# ⠙ Worker assigned... View app at wcfzEDY
# ⠼ Worker assigned... View app at wcfzEDY
# ⠧ Worker assigned... View app at wcfzEDY
# ⠋ Worker assigned... View app at wcfzEDY
# ⠼ Worker assigned... View app at wcfzEDY
# ⠧ Worker assigned... View app at wcfzEDY
# ⠋ Loading images (1 containers initializing)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# dal.com/apps/kshitijchaudhary21/main/ap-FxfPVlFq20XyEIEwcfzEDY
# ⠸ Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/kshitijc
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]Fetching 2 files:  50%|█████     | 1/2 [00:26<00:26, 26.86s/it]Fetching 2 files: 100%|██████████| 2/2 [00:26<00:00, 13.43s/it]
# ⠋ Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/kshitijc
# ⠸ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠋ Running (1/1 containers active)... View app at
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# dal.com/apps/kshitijchaudhary21/main/ap-FxfPVlFq20XyEIEwcfzEDY
# ⠋ Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/kshitijc
# ⠸ Running (1/1 containers active)... View app at
# ⠦ Running (1/1 containers active)... View app at
# ⠏ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading checkpoint shards:  50%|█████     | 1/2 [00:01<00:01,  1.39s/it]Loading checkpoint shards: 100%|██████████| 2/2 [00:01<00:00,  1.16it/s]Loading checkpoint shards: 100%|██████████| 2/2 [00:01<00:00,  1.06it/s]
# ⠦ Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/kshitijc
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# ⠏ Running (1/1 containers active)... View app at 7mView app at https://modal.com/apps/kshitijc
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠹ Running (1/1 containers active)... View app at
# ⠴ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠇ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠼ Running (1/1 containers active)... View app at
# ⠧ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# ⠙ Running (1/1 containers active)... View app at
# https://modal.com/apps/kshitijchaudhary21/main/ap-FxfPVlFq20XyEIEwcfzEDY
# Stopping app - local entrypoint completed.
# ✓ App completed. View run at
# https://modal.com/apps/kshitijchaudhary21/main/ap-FxfPVlFq20XyEIEwcfzEDY
# 'Never gonna give you up, never gonna let you down, never gonna run around and desert you. Never gonna make you cry, never gonna say goodbye. Never gonna tell a lie and hurt you. Never gonna be untrue. Never gonna be untrue. Never gonna be unfaithful.'

# %%
from price_ephemeral import price, app

with modal.enable_output():
    with app.run():
        result = price.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
result
